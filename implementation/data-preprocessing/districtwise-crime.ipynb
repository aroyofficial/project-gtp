# %%
# import the dataset
import pandas as pd
df = pd.read_csv('crime_by_district_rt.csv')
df
# Out:
#             STATE/UT       DISTRICT  Year  Murder  Assault on women  \
# 0     ANDHRA PRADESH       ADILABAD  2001       0                 1
# 1     ANDHRA PRADESH      ANANTAPUR  2001       0                 4
# 2     ANDHRA PRADESH       CHITTOOR  2001       3                 3
# 3     ANDHRA PRADESH       CUDDAPAH  2001       0                 3
# 4     ANDHRA PRADESH  EAST GODAVARI  2001       1                 3
# ...              ...            ...   ...     ...               ...
# 9380        Delhi UT            STF  2013       0                 0
# 9381        Delhi UT           WEST  2013       0                 0
# 9382     Lakshadweep    LAKSHADWEEP  2013       0                 0
# 9383      Puducherry       KARAIKAL  2013       0                 1
# 9384      Puducherry     PUDUCHERRY  2013       0                 0
#
#       Kidnapping and Abduction  Dacoity  Robbery  Arson  Hurt  \
# 0                            4        0        0      0     3
# ...

# %%
# check the null values in the dataset
df.isnull().sum()
# Out:
# STATE/UT                                0
# DISTRICT                                0
# Year                                    0
# Murder                                  0
# Assault on women                        0
# Kidnapping and Abduction                0
# Dacoity                                 0
# Robbery                                 0
# Arson                                   0
# Hurt                                    0
# Prevention of atrocities (POA) Act      0
# Protection of Civil Rights (PCR) Act    0
# Other Crimes Against SCs                0
# dtype: int64

# %%
# label encode the District and Year and State/UT Column
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df.iloc[:, 0] = enc.fit_transform(df.iloc[:, 0])
df.iloc[:, 1] = enc.fit_transform(df.iloc[:, 1])
df.iloc[:, 2] = enc.fit_transform(df.iloc[:, 2])
df
# Out:
#       STATE/UT  DISTRICT  Year  Murder  Assault on women  \
# 0            2         3     0       0                 1
# 1            2        31     0       0                 4
# 2            2       158     0       3                 3
# 3            2       175     0       0                 3
# 4            2       226     0       1                 3
# ...        ...       ...   ...     ...               ...
# 9380        19       740    12       0                 0
# 9381        19       824    12       0                 0
# 9382        37       468    12       0                 0
# 9383        54       396    12       0                 1
# 9384        54       608    12       0                 0
#
#       Kidnapping and Abduction  Dacoity  Robbery  Arson  Hurt  \
# 0                            4        0        0      0     3
# 1                            0        0        0      0    49
# 2                            0        0        0      0    38
# ...
