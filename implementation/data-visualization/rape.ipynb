# %%
# import the dataset for 2016 rape victims
import pandas as pd
df1 = pd.read_csv('2016 Victims of Rape.csv')
df1.drop(['Cases Reported', 'Category'], axis = 1, inplace = True)
age_dict = {
    'Child Victims of Rape (Below 18 Yrs) - Below 6 Years': '<6',
    'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above - Below 12 Years': '>=6-<12',
    'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above - Below 16 Years': '>=12-<16',
    'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above - Below 18 Years': '>=16-<18',
    'Child Victims of Rape (Below 18 Yrs) - Total Girl /Child Victims': 'Total Child Victims',
    'Women Victims of Rape (Above 18 Yrs) - 18 Years & Above - Below 30 Years': '>=18-<30',
    'Women Victims of Rape (Above 18 Yrs) - 30 Years & Above - Below 45 Years': '>=30-<45',
    'Women Victims of Rape (Above 18 Yrs) - 45 Years & Above - Below 60 Years': '>=45-<60',
    'Women Victims of Rape (Above 18 Yrs) - 60 Years & Above': '>=60',
    'Women Victims of Rape (Above 18 Yrs) - Total Women/Adult Victims': 'Total Adult Victims',
    'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above': '>=6-<12',
    'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above': '>=12-<16',
    'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above': '>=16-<18',
    'State/UT': 'Area'
}
df1.rename(columns = age_dict, inplace = True)
df1.drop([df1.columns[0]], axis = 1, inplace = True)
df1
# Out:
#                  Area   <6  >=6-<12  >=12-<16  >=16-<18  Total Child Victims  \
# 0      Andhra Pradesh   14       46       185       296                  541
# 1   Arunachal Pradesh    1        9        19        13                   42
# 2               Assam    2       44        29        25                  100
# 3               Bihar    0        0         0         0                    0
# 4        Chhattisgarh   47       77       396       614                 1134
# 5                 Goa    4        5        31        16                   56
# 6             Gujarat    0        0         0         2                    2
# 7             Haryana    5        7        73        52                  137
# 8    Himachal Pradesh    7       18        52        68                  145
# 9     Jammu & Kashmir    1        5        21        16                   43
# 10          Jharkhand    0        2        10        72                   84
# 11          Karnataka    0        0         0         1                    1
# 12             Kerala   32      115       372       566                 1085
# 13     Madhya Pradesh   50      207      1275      1550                 3082
# 14        Maharashtra    1        2         3         6                   12
# 15            Manipur    0        0         0         2                    2
# 16          Meghalaya    5       18        13        10                   46
# 17            Mizoram    0        0         0         0                    0
# 18           Nagaland    0        0         1         0                    1
# 19             Odisha    2       15       254      1026                 1297
# 20             Punjab    3        9        55        59                  126
# 21          Rajasthan    7       29       156       320                  512
# 22             Sikkim    0        0         0         0                    0
# 23         Tamil Nadu    0        0         0         0                    0
# 24          Telangana    0        0         0         0                    0
# 25            Tripura    1        0         1         3                    5
# 26      Uttar Pradesh  105      190       713       552                 1560
# 27        Uttarakhand    8       12        71        69                  160
# 28        West Bengal    0        0         0         0                    0
# 29      A & N Islands    0        0         0         1                    1
# 30         Chandigarh    3        6        29         7                   45
# 31         D&N Haveli    0        0         0         0                    0
# 32        Daman & Diu    0        2         0         0                    2
# 33           Delhi UT    0        0         0         0                    0
# 34        Lakshadweep    0        0         0         0                    0
# 35         Puducherry    0        0         0         0                    0
#
#     >=18-<30  >=30-<45  >=45-<60  >=60  Total Adult Victims  Total Victims
# 0        333       121         6     4                  464           1005
# 1         24         5         0     0                   29             71
# 2       1291       582        75     0                 1948           2048
# 3        546        68         2     0                  616            616
# 4        525       245        14     8                  792           1926
# 5         13         6         1     0                   20             76
# 6        349       125         2     1                  477            479
# 7        692       246        26     3                  967           1104
# 8         78        23         5     0                  106            251
# 9        163        88         4     0                  255            298
# 10       632       203         8     0                  843            927
# 11       452        94         9     2                  557            558
# 12       595       288        42    25                  950           2035
# 13      1651       716       104    46                 2517           5599
# 14      1428       454        34    17                 1933           1945
# 15        24        15         0     0                   39             41
# 16        47        22         4     0                   73            119
# 17        13         8         2     2                   25             25
# 18         3         5         0     1                    9             10
# 19       737        48         0     0                  785           2082
# 20       310        98        14     2                  424            550
# 21      1988       744        71     4                 2807           3319
# 22        12         4         1     0                   17             17
# 23       230        44         4     5                  283            283
# 24       502       178        14     5                  699            699
# 25        55        35         5     1                   96            101
# 26      2313       779         9     8                 3109           4669
# 27       189        41         6     1                  237            397
# 28       799       263        21     1                 1084           1084
# 29         8         4         0     0                   12             13
# 30        16         4         0     0                   20             65
# 31         1         0         0     0                    1              1
# 32         3         2         0     0                    5              7
# 33       871       337        20     3                 1231           1231
# 34         0         0         0     0                    0              0
# 35         7         0         0     0                    7              7

# %%
# import the dataset for 2017 rape victims
df2 = pd.read_csv('2017 Victims of Rape.csv')
df2.drop(['Cases Reported', 'Category'], axis = 1, inplace = True)
df2.rename(columns = age_dict, inplace = True)
df2.drop([df2.columns[0]], axis = 1, inplace = True)
df2
# Out:
#                  Area   <6  >=6-<12  >=12-<16  >=16-<18  Total Child Victims  \
# 0      Andhra Pradesh   14       46       185       296                  541
# 1   Arunachal Pradesh    1        9        19        13                   42
# 2               Assam    2       44        29        25                  100
# 3               Bihar    0        0         0         0                    0
# 4        Chhattisgarh   47       77       396       614                 1134
# 5                 Goa    4        5        31        16                   56
# 6             Gujarat    0        0         0         2                    2
# 7             Haryana    5        7        73        52                  137
# 8    Himachal Pradesh    7       18        52        68                  145
# 9     Jammu & Kashmir    1        5        21        16                   43
# 10          Jharkhand    0        2        10        72                   84
# 11          Karnataka    0        0         0         1                    1
# 12             Kerala   32      115       372       566                 1085
# 13     Madhya Pradesh   50      207      1275      1550                 3082
# 14        Maharashtra    1        2         3         6                   12
# 15            Manipur    0        0         0         2                    2
# 16          Meghalaya    5       18        13        10                   46
# 17            Mizoram    0        0         0         0                    0
# 18           Nagaland    0        0         1         0                    1
# 19             Odisha    2       15       254      1026                 1297
# 20             Punjab    3        9        55        59                  126
# 21          Rajasthan    7       29       156       320                  512
# 22             Sikkim    0        0         0         0                    0
# 23         Tamil Nadu    0        0         0         0                    0
# 24          Telangana    0        0         0         0                    0
# 25            Tripura    1        0         1         3                    5
# 26      Uttar Pradesh  105      190       713       552                 1560
# 27        Uttarakhand    8       12        71        69                  160
# 28        West Bengal    0        0         0         0                    0
# 29      A & N Islands    0        0         0         1                    1
# 30         Chandigarh    3        6        29         7                   45
# 31         D&N Haveli    0        0         0         0                    0
# 32        Daman & Diu    0        2         0         0                    2
# 33           Delhi UT    0        0         0         0                    0
# 34        Lakshadweep    0        0         0         0                    0
# 35         Puducherry    0        0         0         0                    0
#
#     >=18-<30  >=30-<45  >=45-<60  >=60  Total Adult Victims  Total Victims
# 0        333       121         6     4                  464           1005
# 1         24         5         0     0                   29             71
# 2       1291       582        75     0                 1948           2048
# 3        546        68         2     0                  616            616
# 4        525       245        14     8                  792           1926
# 5         13         6         1     0                   20             76
# 6        349       125         2     1                  477            479
# 7        692       246        26     3                  967           1104
# 8         78        23         5     0                  106            251
# 9        163        88         4     0                  255            298
# 10       632       203         8     0                  843            927
# 11       452        94         9     2                  557            558
# 12       595       288        42    25                  950           2035
# 13      1651       716       104    46                 2517           5599
# 14      1428       454        34    17                 1933           1945
# 15        24        15         0     0                   39             41
# 16        47        22         4     0                   73            119
# 17        13         8         2     2                   25             25
# 18         3         5         0     1                    9             10
# 19       737        48         0     0                  785           2082
# 20       310        98        14     2                  424            550
# 21      1988       744        71     4                 2807           3319
# 22        12         4         1     0                   17             17
# 23       230        44         4     5                  283            283
# 24       502       178        14     5                  699            699
# 25        55        35         5     1                   96            101
# 26      2313       779         9     8                 3109           4669
# 27       189        41         6     1                  237            397
# 28       799       263        21     1                 1084           1084
# 29         8         4         0     0                   12             13
# 30        16         4         0     0                   20             65
# 31         1         0         0     0                    1              1
# 32         3         2         0     0                    5              7
# 33       871       337        20     3                 1231           1231
# 34         0         0         0     0                    0              0
# 35         7         0         0     0                    7              7

# %%
# import the dataset for 2018 rape victims
df3 = pd.read_csv('2018 Victims of Rape.csv')
df3.drop(['Cases Reported', 'Category'], axis = 1, inplace = True)
age = {
    'Child Victims of Rape (Below 18 Yrs) - Below 6 Years': '<6',
    'Child Victims of Rape (Below 18 Yrs) - Total Girl /Child Victims': 'Total Child Victims',
    'Child Victims of Rape (Below 18 Yrs) - 6 Years & Above ': '>=6-<12',
    'Child Victims of Rape (Below 18 Yrs) - 12 Years & Above ': '>=12-<16',
    'Child Victims of Rape (Below 18 Yrs) - 16 Years & Above ': '>=16-<18',
    'Child Victims of Rape (Below 18 Yrs) - Total Girl/Child Victims': 'Total Child Victims',
    'Women Victims of Rape (Above 18 Yrs) - 18 Years & Above - Below 30 Years': '>=18-<30',
    'Women Victims of Rape (Above 18 Yrs) - 30 Years & Above - Below 45 Years': '>=30-<45',
    'Women Victims of Rape (Above 18 Yrs) - 45 Years & Above - Below 60 Years': '>=45-<60',
    'Women Victims of Rape (Above 18 Yrs) - 60 Years & Above': '>=60',
    'Women Victims of Rape (Above 18 Yrs) - Total Women/Adult Victims': 'Total Adult Victims',
    'State/UT ': 'Area'
}
df3.rename(columns = age, inplace = True)
df3.drop([df3.columns[0]], axis = 1, inplace = True)
df3
# Out:
#                  Area  <6  >=6-<12  >=12-<16  >=16-<18  Total Child Victims  \
# 0      Andhra Pradesh  16       57       181       251                  505
# 1   Arunachal Pradesh   4        4        13        11                   32
# 2               Assam   7       24         6        52                   89
# 3               Bihar   0        0         1         3                    4
# 4        Chhattisgarh  41       80       557       541                 1219
# 5                 Goa   0        1        21        12                   34
# 6             Gujarat   0        0         3         4                    7
# 7             Haryana   2        0         0         0                    2
# 8    Himachal Pradesh   2       25        85        84                  196
# 9     Jammu & Kashmir   0        6        18        18                   42
# 10          Jharkhand   0        0         6        63                   69
# 11          Karnataka   0        0         2         2                    4
# 12             Kerala  48      129       334       645                 1156
# 13     Madhya Pradesh  54      142      1143      1502                 2841
# 14        Maharashtra   0        0         0         0                    0
# 15            Manipur   0        1         7         9                   17
# 16          Meghalaya   0        4         6        15                   25
# 17            Mizoram   2       12         8         1                   23
# 18           Nagaland   0        0         1         2                    3
# 19             Odisha   0        0        10        27                   37
# 20             Punjab  10       30       151       139                  330
# 21          Rajasthan  17       48       392       575                 1032
# 22             Sikkim   0        0         0         4                    4
# 23         Tamil Nadu   1        1         1         3                    6
# 24          Telangana   0        0         0         0                    0
# 25            Tripura   0        0         0         0                    0
# 26      Uttar Pradesh  67      174       570       600                 1411
# 27        Uttarakhand   3        5        79       186                  273
# 28        West Bengal   0        0         1         3                    4
# 29      A & N Islands   0        1         3        10                   14
# 30         Chandigarh   7       13        16        17                   53
# 31         D&N Haveli   0        0         0         0                    0
# 32        Daman & Diu   0        0         1         0                    1
# 33           Delhi UT   0        0         0         0                    0
# 34        Lakshadweep   0        0         0         0                    0
# 35         Puducherry   0        0         0         0                    0
#
#     >=18-<30  >=30-<45  >=45-<60  >=60  Total Adult Victims  Total Victims
# 0        373        76        14     5                  468            973
# 1         29         9         0     0                   38             70
# 2       1043       523       107     5                 1678           1767
# 3        520       111        16     0                  647            651
# 4        644       190        42     6                  882           2101
# 5         13        11         2     1                   27             61
# 6        389       144        12     1                  546            553
# 7        969       300        22     3                 1294           1296
# 8        101        45         6     1                  153            349
# 9        172       109         5     0                  286            328
# 10       798       217        14     0                 1029           1098
# 11       369       120         3     1                  493            497
# 12       465       294        43    14                  816           1972
# 13      1798       725        75    11                 2609           5450
# 14      1524       552        62    11                 2149           2149
# 15        27         7         1     0                   35             52
# 16        49        14         1     0                   64             89
# 17        20         5         1     1                   27             50
# 18         5         1         1     1                    8             11
# 19       835        47         4     0                  886            923
# 20       381       108        15     3                  507            837
# 21      2263       912       129     1                 3305           4337
# 22         5         4         3     0                   12             16
# 23       256        63         6     1                  326            332
# 24       465       123        17     1                  606            606
# 25        73        21         3     0                   97             97
# 26      2235       603        70     3                 2911           4322
# 27       194       101         8     0                  303            576
# 28       736       310        18     1                 1065           1069
# 29        12         3         1     0                   16             30
# 30        14        12         7     0                   33             86
# 31         6         1         0     0                    7              7
# 32         2         0         0     0                    2              3
# 33       851       345        19     2                 1217           1217
# 34         0         2         0     0                    2              2
# 35         0         0         0     0                    0              0

# %%
import matplotlib.pyplot as plt
import numpy as np
def analysis(df, s):
    x = np.arange(len(df))
    w = 0.2
    plt.figure(figsize = (12, 8))
    plt.bar(x, df.iloc[:, 1], w)
    plt.bar(x + w,  df.iloc[:, 2], w)
    plt.bar(x + 2 * w,  df.iloc[:, 3], w)
    plt.bar(x + 3 * w,  df.iloc[:, 4], w)
    plt.bar(x + 4 * w,  df.iloc[:, 6], w)
    plt.bar(x + 5 * w,  df.iloc[:, 7], w)
    plt.bar(x + 6 * w,  df.iloc[:, 8], w)
    plt.bar(x + 7 * w,  df.iloc[:, 9], w)
    plt.xticks(x, df.iloc[:, 0], rotation = 90)
    s = s + 'Rape Victims Analysis'
    plt.title(s)
    plt.ylabel('No. of Victims')
    plt.legend(['<6', '>=6-<12', '>=12-<16', '>=16-<18', '>=18-<30', '>=30-<45', '>=45-<60', '>=60'])
    plt.show()

# %%
analysis(df1, '2016')
analysis(df1, '2017')
analysis(df1, '2018')
