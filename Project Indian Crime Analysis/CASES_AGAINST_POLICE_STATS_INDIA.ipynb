# %% [markdown]
# <h1><b><font color = black><a id='division_ID0'>2016 - 2018 INDIA CASES AGAINST POLICE STATISTICS</a></font></b></h1><br>
# <b>Built by Arijit Roy, Arkadeep Roy, Soumodip Ghosh, Ankita Datta, Shayani Das</b>
# <br><b>Guidance - Indranil Das, Technical Analyst, Webskitters Academy</b>
# <br><b>In Association with Webskitters Academy</b>
# <br><b>Hooghly Engineering & Technology College</b>
#
# <p><b>Download Dataset Dependency - <a href = "https://drive.google.com/drive/folders/1Yg-mCzVi_9G8CfACKB03V8UOQVc6Cksm?usp=sharing">Click here</a></b></p>
#
# <h3><b>Contents</b></h3>
#
# [Data Collection](#division_ID1) | [Data Preprocessing](#division_ID2) | [Data Visualization](#division_ID3)

# %% [markdown]
# <h2><a id='division_ID1'>Data Collection</a></h2>
#
# [MENU](#division_ID0)

# %%
# import datasets from the local repository
import pandas as pd
df1 = pd.read_csv('2016 Cases against Police Personnels.csv')
df2 = pd.read_csv('2017 Cases against Police Personnels.csv')
df3 = pd.read_csv('2018 Cases against Police Personnels.csv')

# %% [markdown]
# <h2><a id='division_ID2'>Data Preprocessing</a></h2>
#
# [MENU](#division_ID0)

# %%
# check null values in the dataset
print(df1.isnull().sum())
print(df2.isnull().sum())
print(df3.isnull().sum())
# Out:
# S. No.                                                       0
# Category                                                     0
# State/UT                                                     0
# Total Number of Criminal Cases Registered during the year    0
# Police Personnel Arrested                                    0
# Cases Chargesheeted                                          0
# Police Personnel Chargesheeted                               0
# Police Personnel whose Cases were withdrawn/ Disposed Off    0
# Police Personnel whose Trials were Completed                 0
# Police Personnel Convicted                                   0
# Police Personnel Acquitted                                   0
# dtype: int64
# S. No.                                                      0
# Category                                                    0
# State/UT                                                    0
# Number of Cases - Registered                                0
# Number of Cases - Quashed/Stayed by Courts                  0
# Number of Cases - Chargesheeted                             0
# Number of Cases - Final Report Submitted                    0
# Number of Police Personel - Arrested                        0
# Number of Police Personel - Chargesheeted                   0
# Number of Police Personel - Cases Withdrawn/Disposed Off    0
# Number of Police Personel - Trials were Completed           0
# Number of Police Personel - Convicted                       0
# Number of Police Personel - Acquitted or Discharged         0
# dtype: int64
# S. No.                                                      0
# Category                                                    0
# State/UT                                                    0
# Number of Cases - Registered                                0
# Number of Cases - Quashed/Stayed by Courts                  0
# Number of Cases - Chargesheeted                             0
# Number of Cases - Final Report Submitted                    0
# Number of Police Personel - Arrested                        0
# Number of Police Personel - Chargesheeted                   0
# Number of Police Personel - Cases Withdrawn/Disposed Off    0
# Number of Police Personel - Trials were Completed           0
# Number of Police Personel - Convicted                       0
# Number of Police Personel - Acquitted or Discharged         0
# dtype: int64

# %%
# preprocess df1
df1 = df1.iloc[:, [2, 3, 4, 5, 6]]
df1.rename(columns={'Total Number of Criminal Cases Registered during the year': 'Total Cases', 'Police Personnel Arrested': 'Police Arrested', 'Cases Chargesheeted': 'Chargesheets', 'Police Personnel Chargesheeted': 'Chargesheet against police'}, inplace = True)
df1
# Out:
#              State/UT  Total Cases  Police Arrested  Chargesheets  \
# 0      Andhra Pradesh          100               36            28
# 1   Arunachal Pradesh           24               10            13
# 2               Assam           37               18             8
# 3               Bihar           43                0            40
# 4        Chhattisgarh           65               26            32
# 5                 Goa           20               11             8
# 6             Gujarat          130              131            91
# 7             Haryana           34               41            18
# 8    Himachal Pradesh           11                7             5
# 9     Jammu & Kashmir           29               22            15
# 10          Jharkhand            3                2             2
# 11          Karnataka           63               23            16
# 12             Kerala          171               50            49
# 13     Madhya Pradesh           66               44            61
# 14        Maharashtra          487              388           196
# 15            Manipur            0               19             0
# 16          Meghalaya          265                2           110
# 17            Mizoram            0                0             0
# 18           Nagaland           12               11             4
# 19             Odisha           64               35            28
# 20             Punjab           88               70            16
# 21          Rajasthan          158               30            33
# 22             Sikkim            0                0             0
# 23         Tamil Nadu          114               57            41
# 24          Telangana           57               33            29
# 25            Tripura           10                7             6
# 26      Uttar Pradesh          315              187           108
# 27        Uttarakhand            7                7             4
# 28        West Bengal            9                3            18
# 29      A & N Islands            0                0             0
# 30         Chandigarh           13               14            14
# 31         D&N Haveli            0                0             0
# 32        Daman & Diu            1                5             0
# 33              Delhi          136               42             2
# 34        Lakshadweep            0                0             0
# 35         Puducherry           96                0            96
#
#     Chargesheet against police
# 0                           29
# 1                           13
# 2                            8
# 3                           40
# 4                           38
# 5                            8
# 6                          105
# 7                           26
# 8                            5
# 9                           17
# 10                           2
# 11                          16
# 12                          42
# 13                          65
# 14                         209
# 15                           0
# 16                           0
# 17                           0
# 18                           5
# 19                          25
# 20                          22
# 21                          31
# 22                           0
# 23                          42
# 24                          29
# 25                           6
# 26                         182
# 27                           7
# 28                          18
# 29                           0
# 30                          16
# 31                           0
# 32                           0
# 33                           2
# 34                           0
# 35                          96

# %%
# preprocess df2
df2 = df2.iloc[:, [2, 3, 7, 5, 8]]
df2.rename(columns={'Number of Cases - Registered': 'Total Cases', 'Number of Police Personel - Arrested': 'Police Arrested', 'Number of Cases - Chargesheeted': 'Chargesheets', 'Number of Police Personel - Chargesheeted': 'Chargesheet against police'}, inplace = True)
df2
# Out:
#              State/UT  Total Cases  Police Arrested  Chargesheets  \
# 0      Andhra Pradesh          164              103           344
# 1   Arunachal Pradesh            9                0             1
# 2               Assam            8                0             1
# 3               Bihar            4                0             4
# 4        Chhattisgarh           20                0            10
# 5                 Goa           25               11             2
# 6             Gujarat          191              178           125
# 7             Haryana           39                0            23
# 8    Himachal Pradesh            9               16            21
# 9     Jammu & Kashmir           40                0            52
# 10          Jharkhand            2                0             0
# 11          Karnataka           45                0            14
# 12             Kerala          114               45            16
# 13     Madhya Pradesh           50                0            60
# 14        Maharashtra          456                0           237
# 15            Manipur            0                0             0
# 16          Meghalaya            1                0             0
# 17            Mizoram            1                0             1
# 18           Nagaland           14                0             1
# 19             Odisha           44                0            23
# 20             Punjab          114               45            26
# 21          Rajasthan          169                0            82
# 22             Sikkim            0                0             0
# 23         Tamil Nadu          116                0            23
# 24          Telangana           87               47            18
# 25            Tripura            4                2             0
# 26      Uttar Pradesh          106               88            36
# 27        Uttarakhand            2                2             1
# 28        West Bengal           23                0            15
# 29      A & N Islands            8                7             7
# 30         Chandigarh            8                0            11
# 31         D&N Haveli            0                0             0
# 32        Daman & Diu            0                0             0
# 33           Delhi UT           13                5             4
# 34        Lakshadweep            0                0             0
# 35         Puducherry          119                0            63
#
#     Chargesheet against police
# 0                          101
# 1                            5
# 2                            1
# 3                            5
# 4                           17
# 5                           11
# 6                          176
# 7                           23
# 8                           16
# 9                           28
# 10                           0
# 11                          29
# 12                          31
# 13                          48
# 14                         232
# 15                           0
# 16                           0
# 17                           0
# 18                           6
# 19                          12
# 20                          38
# 21                          29
# 22                           0
# 23                          23
# 24                          44
# 25                           2
# 26                          81
# 27                           2
# 28                          15
# 29                           7
# 30                          11
# 31                           0
# 32                           0
# 33                           5
# 34                           0
# 35                           2

# %%
# preprocess df3
df3 = df3.iloc[:, [2, 3, 7, 5, 8]]
df3.rename(columns={'Number of Cases - Registered': 'Total Cases', 'Number of Police Personel - Arrested': 'Police Arrested', 'Number of Cases - Chargesheeted': 'Chargesheets', 'Number of Police Personel - Chargesheeted': 'Chargesheet against police'}, inplace = True)
df3
# Out:
#              State/UT  Total Cases  Police Arrested  Chargesheets  \
# 0      Andhra Pradesh           97                0            45
# 1   Arunachal Pradesh            5                0             0
# 2               Assam           30                0             5
# 3               Bihar           17                0            11
# 4        Chhattisgarh          255               19             3
# 5                 Goa           10                0             0
# 6             Gujarat          170              174           125
# 7             Haryana           64                0            46
# 8    Himachal Pradesh           13                0             5
# 9     Jammu & Kashmir           47                0             0
# 10          Jharkhand            2                0             0
# 11          Karnataka           92                0            38
# 12             Kerala           97                6            31
# 13     Madhya Pradesh          172               18            97
# 14        Maharashtra          401              319           197
# 15            Manipur            2                0             0
# 16          Meghalaya            0                0             0
# 17            Mizoram            3                0             0
# 18           Nagaland            3                0             0
# 19             Odisha           19                4             1
# 20             Punjab          286                0            17
# 21          Rajasthan         3340                3          2138
# 22             Sikkim            0                0             0
# 23         Tamil Nadu           71               26             7
# 24          Telangana          111                0            48
# 25            Tripura           11                0             1
# 26      Uttar Pradesh           90                0            32
# 27        Uttarakhand            5                3             2
# 28        West Bengal           46                0             9
# 29      A & N Islands           11                7             0
# 30         Chandigarh            2                1             0
# 31         D&N Haveli            0                0             0
# 32        Daman & Diu            0                0             0
# 33           Delhi UT            7                0             4
# 34        Lakshadweep            0                0             0
# 35         Puducherry            0                0             0
#
#     Chargesheet against police
# 0                           61
# 1                            0
# 2                            5
# 3                           63
# 4                           12
# 5                            9
# 6                          163
# 7                           26
# 8                            9
# 9                           40
# 10                           0
# 11                          17
# 12                          31
# 13                          73
# 14                         197
# 15                           0
# 16                           0
# 17                           2
# 18                           0
# 19                           4
# 20                          18
# 21                          26
# 22                           0
# 23                          19
# 24                          46
# 25                           1
# 26                          46
# 27                           0
# 28                          35
# 29                           7
# 30                           3
# 31                           0
# 32                           0
# 33                           5
# 34                           0
# 35                           0

# %% [markdown]
# <h2><a id='division_ID3'>Data Visualization</a></h2>
#
# [MENU](#division_ID0)

# %% [markdown]
# - <h3><b>2016 - 2018 Chargesheets Against Police Statewise Overall Comaparison</b></h3>

# %%
import matplotlib.pyplot as plt 
import numpy as np
areas = list(df1.iloc[:, 0])
r = np.arange(len(areas))
w = 0.3
plt.figure(figsize = (16, 9))
plt.bar(r, list(df1.iloc[:, -1]), w)
plt.bar(r+w, list(df2.iloc[:, -1]), w)
plt.bar(r+w*2, list(df3.iloc[:, -1]), w)
plt.xticks(r+w, areas, rotation = 90)
plt.title('2016 - 2018 Chargesheets Against Poilce ', bbox = {'facecolor': '0.8', 'pad': 5}, loc = 'center')
plt.legend(['2016 Chargesheets against Police', '2017 Chargesheets against Police', '2018 Chargesheets against Police'])
plt.show()

# %% [markdown]
# - <h3><b>2016 - 2018 Cases Against Police Statewise Overall Comaparison</b></h3>

# %%
r = np.arange(len(areas))
w = 0.3
plt.figure(figsize = (16, 9))
plt.bar(r, list(df1.iloc[:, 1]), w)
plt.bar(r+w, list(df2.iloc[:, 1]), w)
plt.bar(r+w*2, list(df3.iloc[:, 1]), w)
plt.xticks(r+w, areas, rotation = 90)
plt.title('2016 - 2018 Cases Against Poilce ', bbox = {'facecolor': '0.8', 'pad': 5}, loc = 'center')
plt.legend(['2016 Cases against Police', '2017 Cases against Police', '2018 Cases against Police'])
plt.show()

# %% [markdown]
# - <h3><b>2016 - 2018 Chargesheets Against Police Statewise Overall Comaparison [Geographical]</b></h3>

# %%
chargesheets = []
for i in range(36):
    chargesheets.append(df1.iloc[i, -1] + df2.iloc[i, -1] + df3.iloc[i, -1])
import geopandas as gpd
df = pd.DataFrame(list(zip(list(df1.iloc[:, 0]), chargesheets)), columns = ['Area_Name', 'Frequency'])
map_file = gpd.read_file('Indian_States.shp')
merged = map_file.set_index('st_nm').join(df.set_index('Area_Name'))
na = ['Andaman & Nicobar Island', 'Arunanchal Pradesh', 'Dadara & Nagar Havelli', 
      'NCT of Delhi', 'Telangana', 'Puducherry', 'Lakshadweep', 'Sikkim', 'Uttarakhand', 'Goa']
val = [14, 18, 0, 0, 0, 98, 0, 0, 9, 28]
j = 0
for i in na:
    merged.at[i, list(merged.columns)[1]] = val[j]
    j += 1
merged.iloc[:, -1] = merged.iloc[:, -1].astype(int)
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('2001 - 2010 Statewise Comparison [Chargesheets Against Police]', bbox={'facecolor':'0.8', 'pad':5}, loc = 'center')
fig = merged.plot(column='Frequency', cmap='gnuplot', linewidth=0.5, ax=ax, edgecolor='0.1',legend=True)

# %% [markdown]
# - <h3><b>2016 - 2018 Cases Against Police Statewise Overall Comaparison [Geographical]</b></h3>

# %%
cases = []
for i in range(36):
    cases.append(df1.iloc[i, -1] + df2.iloc[i, -1] + df3.iloc[i, -1])
df = pd.DataFrame(list(zip(list(df1.iloc[:, 0]), cases)), columns = ['Area_Name', 'Frequency'])
map_file = gpd.read_file('Indian_States.shp')
merged = map_file.set_index('st_nm').join(df.set_index('Area_Name'))
na = ['Andaman & Nicobar Island', 'Arunanchal Pradesh', 'Dadara & Nagar Havelli', 
      'NCT of Delhi', 'Telangana', 'Puducherry', 'Lakshadweep', 'Sikkim', 'Uttarakhand', 'Goa']
val = [14, 18, 0, 0, 0, 98, 0, 0, 9, 28]
j = 0
for i in na:
    merged.at[i, list(merged.columns)[1]] = val[j]
    j += 1
merged.iloc[:, -1] = merged.iloc[:, -1].astype(int)
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('2001 - 2010 Statewise Comparison [Chargesheets Against Police]', bbox={'facecolor':'0.8', 'pad':5}, loc = 'center')
fig = merged.plot(column='Frequency', cmap='gist_ncar', linewidth=0.5, ax=ax, edgecolor='0.1',legend=True)

# %% [markdown]
# <center>For further information or query mail us at <a href = "mailto: aroy02072000@gmail.com">aroy02072000@gmail.com</a></center>
#
#
# <br><center>&copy; All rights reserved by Webskitters Academy</center>
